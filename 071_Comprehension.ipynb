# %% [markdown]
# <a href="https://colab.research.google.com/github/jh981117/Study_Python/blob/main/071_Comprehension.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comprehension

# %%
# List Comprehension  -->  list 안에 포함된 for문  --> list 생성
# Dict Comprehension  -->  dict 안에 포함된 for문 --> dict 생성
# Set Comprehension -->  set 안에 포함된 for문 --> set 생성

# %% [markdown]
# # List Comprehension

# %%
# List Comprehension 구문
# [표현식 for 항목 in 반복가능객체 (if 조건)]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 주어진 리스트의 원소 데이터 들을 * 3 하여 새로운 리스트 작성하기
# ex) [1, 2, 3, 4] ==> [3, 6, 9, 12]

# 일단 지금까지 배운 방법으로 한다면

a = [1, 2, 3, 4]
result = []

for num in a:
  result.append(num * 3)

print(result)
# Out:
# [3, 6, 9, 12]

# %%
# 그러나 파이썬에는 List Comprehension 이라는 독특한 '리스트 안의 for 문'으로 간단히 리스트 작성 가능

a = [1, 2, 3, 4]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#  짝수에만 3을 곱하여 담고 싶다면 다음과 같이 "if 조건"을 사용할 수 있다
# [1, 2, 3, 4] --> [6, 12]

a = [1, 2, 3, 4]

[num * 3 for num in a if num % 2 == 0]
# Out:
# [6, 12]

# %%
# 아래와 같이 짝수에만 적용되게 하려면? 홀수는 그대로.
# [1, 2, 3, 4]
#  ↓  ↓  ↓  ↓
# [1, 6, 3, 12]   <- 2, 4 에만 x3 적용

a = [1, 2, 3, 4]

[
    num *3 if num % 2 == 0 else num # 삼항연산자 사용
    for num in a
]
# Out:
# [1, 6, 3, 12]

# %%
# for문 2개 이상 사용도 가능

# [표현식 for 항목1 in 반복가능객체1 if 조건1
#         for 항목2 in 반복가능객체2 if 조건2
#         ...
#         for 항목n in 반복가능객체n if 조건n]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
[
    f'{j}-{ch}'
    for j in range(2, 10, 2)  # 2, 4, 6, 8
    for ch in "ABC"
]
# Out:
# ['2-A',
#  '2-B',
#  '2-C',
#  '4-A',
#  '4-B',
#  '4-C',
#  '6-A',
#  '6-B',
#  '6-C',
#  '8-A',
#  '8-B',
#  '8-C']

# %%
# 구구단의 모든 결과를 담는 리스트
"""
['2 x 1 = 2',
 '2 x 2 = 4',
 ...
 '9 x 7 = 63',
 '9 x 8 = 72',
 '9 x 9 = 81']

"""
None

# %%
[
    f'{dan} x {x} = {dan*x}'
    for dan in range(2,10)
    for x in range(1,10)
]
# Out:
# ['2 x 1 = 2',
#  '2 x 2 = 4',
#  '2 x 3 = 6',
#  '2 x 4 = 8',
#  '2 x 5 = 10',
#  '2 x 6 = 12',
#  '2 x 7 = 14',
#  '2 x 8 = 16',
#  '2 x 9 = 18',
#  '3 x 1 = 3',
#  '3 x 2 = 6',
#  '3 x 3 = 9',
#  '3 x 4 = 12',
#  '3 x 5 = 15',
#  '3 x 6 = 18',
#  '3 x 7 = 21',
#  '3 x 8 = 24',
#  '3 x 9 = 27',
#  '4 x 1 = 4',
#  '4 x 2 = 8',
#  '4 x 3 = 12',
#  '4 x 4 = 16',
#  '4 x 5 = 20',
#  '4 x 6 = 24',
#  '4 x 7 = 28',
#  '4 x 8 = 32',
#  '4 x 9 = 36',
#  '5 x 1 = 5',
#  '5 x 2 = 10',
#  '5 x 3 = 15',
#  '5 x 4 = 20',
#  '5 x 5 = 25',
#  '5 x 6 = 30',
#  '5 x 7 = 35',
#  '5 x 8 = 40',
#  '5 x 9 = 45',
#  '6 x 1 = 6',
#  '6 x 2 = 12',
#  '6 x 3 = 18',
#  '6 x 4 = 24',
#  '6 x 5 = 30',
#  '6 x 6 = 36',
#  '6 x 7 = 42',
#  '6 x 8 = 48',
#  '6 x 9 = 54',
#  '7 x 1 = 7',
#  '7 x 2 = 14',
#  '7 x 3 = 21',
#  '7 x 4 = 28',
#  '7 x 5 = 35',
#  '7 x 6 = 42',
#  '7 x 7 = 49',
#  '7 x 8 = 56',
#  '7 x 9 = 63',
#  '8 x 1 = 8',
#  '8 x 2 = 16',
#  '8 x 3 = 24',
#  '8 x 4 = 32',
#  '8 x 5 = 40',
# ...

# %%
[num % 3 for num in range(10)]
# Out:
# [0, 1, 2, 0, 1, 2, 0, 1, 2, 0]

# %% [markdown]
# # Set Comprehension

# %%
{num % 3 for num in range(10)}  # set comprehension # set은 중복된값 허용 x
# Out:
# {0, 1, 2}

# %% [markdown]
# #Dict Comprehension

# %%
result = {n for n in range(5)}
print(result, type(result))
# Out:
# {0, 1, 2, 3, 4} <class 'set'>

# %%
result = {n: n**2 for n in range(5)}  # dict comprehension
print(result, type(result))
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16} <class 'dict'>

# %%
{
    x: list(range(x))
    for x in [1, 2, 3, 4, 5]
}
# Out:
# {1: [0], 2: [0, 1], 3: [0, 1, 2], 4: [0, 1, 2, 3], 5: [0, 1, 2, 3, 4]}
